# %%
'''
author: Joseph Taylor
Student ID: 201599999
'''

# %%
import numpy as np # import numpy
import matplotlib.pyplot as plt # import matplotlib pyplot

# %%
# 1. Understanding the Monte Carlo SIR code structure

Answer_1i = """(i)

The code models the spread of flu through a population of 1000 students using a Monte Carlo simulation \
based on the SIR (Susceptible-Infected-Removed) framework. Each student is represented by an element \
in an array P, where 0 = immune/removed, 1 = susceptible, and 2 = infected.

The structure follows these stages:
  1. Define parameters: number of students (1000), fraction initially immune (1%), recovery probability \
(0.2/day), number of new infections per infected student per day (1), number of days (40), and number \
of repeat simulations (40).
  2. For each repeat, initialise the population array: set all students to susceptible (P[i] = 1), then \
randomly select 1% (10 students) to be immune (P = 0), and randomly select 1 susceptible student to be \
the initial infected case (P = 2).
  3. Run the main simulation: loop over each day, and within each day loop over every student. If a \
student is infected, they randomly choose another student to infect (if that student is susceptible). \
Independently, each student has a 0.2 probability of triggering a recovery event, where a random \
student is checked and if infected, is set to immune/removed.
  4. At the end of each day, count the number of infected and susceptible students and accumulate \
the totals across repeats for averaging.
  5. After all repeats, compute the average number infected per day and the total number of students \
who were infected (the epidemic size)."""

Answer_1ii = """(ii)

There are three nested loops that form the core of the simulation:
  - Outer loop (k from 1 to reps): repeats the entire simulation 40 times with different random \
initial distributions of immune and infected students, so that results can be averaged.
  - Middle loop (j from 1 to numd): loops over the 40 days of the epidemic. Each iteration of this \
loop represents one day passing.
  - Inner loop (i from 1 to nums): loops over all 1000 students each day. For each student, the code \
checks if they are infected and if so, attempts to spread the infection to a randomly chosen student. \
It also checks whether a recovery event occurs (with probability 0.2), and if so, picks a random student \
and removes them from the infected pool if they are infected.

There is also a small inner loop (ii from 1 to num_infect) inside the student loop, which controls how \
many new infections each infected student attempts per day (set to 1 in this case). Finally, a separate \
counting loop at the end of each day tallies the number of infected and susceptible students."""

print(Answer_1i)
print(Answer_1ii)
# Out:
# (i) How the code is structured:
#
# The code models the spread of flu through a population of 1000 students using a Monte Carlo simulation based on the SIR (Susceptible-Infected-Removed) framework. Each student is represented by an element in an array P, where 0 = immune/removed, 1 = susceptible, and 2 = infected.
#
# The structure follows these stages:
#   1. Define parameters: number of students (1000), fraction initially immune (1%), recovery probability (0.2/day), number of new infections per infected student per day (1), number of days (40), and number of repeat simulations (40).
#   2. For each repeat, initialise the population array: set all students to susceptible (P[i] = 1), then randomly select 1% (10 students) to be immune (P = 0), and randomly select 1 susceptible student to be the initial infected case (P = 2).
# ...
